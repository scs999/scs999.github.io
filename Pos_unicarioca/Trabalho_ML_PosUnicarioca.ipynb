# %% [markdown]
# # Pós Graduação em Ciência de Dados
#
# **Machine Learning**
#
# Prof.: Fábio Daudt
#
# 10/2023

# %% [markdown]
# #Linguagem de Processamento Natural (*NLP Natural Language Processing*)

# %% [markdown]
# **SPACY**
#
# bs4
#
# urllib.request
#
# nlkt
#
# spacy
#
# POS (part-of-speech) – Partes do texto
#
# Buscas em textos com Spacy
#
# Ipython (Melhorar visualização html)
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Extração de entidades nomeadas**
#
# NER (Named-Entity Recognition) - Reconhecimento de entidade nomeada
#
# Chatbots para classificar o assunto
#
# Pessoa, Localização, Organização
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Nuvem de palavras Python Matplotlib**
#
# Tokens
#
# stop words
#
# Visualização
#
# matplotlib
# - ListedColorMap (lista de cores )
# - wordCloud

# %% [markdown]
# **Nuvem de palavras utilizando ORANGE**
#
# Data Mining
#
# Open souce
#
# v 3.36.1
#
# datasets, csv, sql, ...
#
#
#
#
# ![Imagem2.png](data:image/png;base64,...)

# %% [markdown]
# # Generative Adversarial Networks (GAN)
#
# Redes Adversarias Generativas (Rede Neural Generativa)
#
# Melhora de resolução de imagens
#
# Criação de imagens de ambientes

# %% [markdown]
# **DALL-E**
# **Criação de imagens**
#
# Open IA
#
# 2021
#
# 12 bilhões de parametros GPT-3 Transformer
#
# Deep Learning baseado em transformers
#
# Necessário cadastrar / Possuir créditos
#
# Necessário gerar uma api-key
#
# Treinamento ( Texto X Imagem)
#
# Prompt com as instruções (ex.: Criar um carro antigo")
#
# Saida URL ou converter imagem
#
# Uma opção gratuita é em https://huggingface.co/spaces/dalle-mini/dalle-mini
#
# ![image.png](data:image/png;base64,...)
#
# * (Seu nome é uma junção de WALL-E e Salvador Dalí. Fonte: Wikipedia)
#
#
# Aplicação Microsoft
#
# ![image.png](data:image/png;base64,...)
#
#
#
# **WHISPER**
#
# **Transcrição de Áudio**
#
# ![Imagem3.png](data:image/png;base64,...)
#
# Open IA
#
# Open Source
#
# Deep Learning baseado em transformers
#
# Carrega arquivo audio
#
# Saida texto

# %% [markdown]
# # Federated Learning (FL)
#
# Aprendizado federado

# %% [markdown]
# ML descentralizada ----- Privacidade das pessoas
#
#     Conectar informações de locais diferentes ---- Conhecimento mais robusto
#     Compartilhamento de aprendizado X Compartilhamento de dados
#     Modelos de ML valores reduzir o que “Previu” X Informação real
#
# Modelo identificação de várias doenças
#
#      Dados de um único hospital – várias doenças
#      Algumas doenças nunca tratadas nesse hospital
#      Modelo não consegue aprender
#
# Smartphones
#
#     Teclado, face, voz
#
# Cidades inteligentes
#
#       "ONU prevê que cidades abriguem 70% da população mundial até 2050"
#       https://news.un.org/pt/story/2019/02/1660701
#
#
#
# Saúde
#
#
#
# Finanças
#
#
#          Em um ambiente tradicional de Machine Learning, para a extração do
#      conhecimento, deve-se enviar o dado para um servidor centralizado, onde
#      acontece todo o processamento necessário.
#
#
# LGPD
#
#     Vazamento de dados
#     Adequação
